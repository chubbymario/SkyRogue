# %% [markdown]
# <a href="https://colab.research.google.com/github/chubbymario/SkyRogue/blob/main/SkyRogue.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import output
import random as ran
import time

# all variables are lists so that i can use global variables without the global module
stats_list = [100, 100, 100, 30, 100, 0, 50] #HP, DEF, STR, CC, CD, FER, SPD
maxMana = [50]
currentMana = [0]
manaRegen = [10]
Base_DMG = [10]
maxHP = [100]
notjerriedbefore = [True] #checks for tutorial completion
notbsmithedbefore = [True, True, True, True] #checks the number of times the armor and weapons have been upgraded
isnotDead = [True] #checks for death
location_completed = [False, False, False, False, False] #checks for completion of locations
bossCounter = ["p_is", 0, 0, "c_isle", "jerry"] #boss counter for the spiders' den (s_den) and end dimension (end) rest are just for decoration
classes = ["no class chosen", "Berserker", "Archer", "Mage"] #list of classes
chosen_class = [0] #current chosen class

ability_list = ["Heal for 10% of your max HP", "Increase damage by 2x for 1 hit", "Apply burn DoT", "70% chance for dodge", "Summon minion as a meat shield that shares your defense"]
ability_cost = [30, 20, 20, 10, 50]
Abt_Heal = [maxHP[0] * 0.1] #healed health
Abt_Double = [1] #increases to 2 for 1 turn
Abt_Burn = [0] #duration and damage (burn decreases over time)
Abt_Dodge = [False] #checks for dodge
dodge_activated = [False]
Abt_Minion = [maxHP[0] * 0.2] #health
abtMinionSummoned = [False] #checks if your minion is summoned

current_wpn = [0] #current best weapon

wpn_list = [["no class chosen", "no class chosen", "no class chosen", "no class chosen", "no class chosen"],
 ["Wooden Sword", "Stone Sword", "Iron Sword", "Diamond Sword", "Netherite Sword"],
 ["Bow of Eth", "Bow of Eng", "Bow of Gar", "Bow of Dagaz", "Bow of Jēran"],
  ["Staff of Nothing", "Awakened Staff", "Recombobulated Staff", "Three-Pronged Staff", "Staff of Perfection"]] #nested list of all weapons in game

flav_text_wpn = [["no class chosen", "no class chosen", "no class chosen", "no class chosen", "no class chosen"],
 ['''
     .
    / \\
    | |
    | |
    | |
    | |
  `--𐤍--'
     8
     0

The sword that started everything.
''', '''
     .
    /:\\
    |||
    |||
    |||
    |||
  `--𐤑--'
     8
     0

An upgrade? It looks cooler, at least.
''', '''
    Λ
   /|\\
   |/|
   |||
   |||
   |||
   |||
   |||
   |||
~-[{𐤁}]-~
   |\|
   |\|
   `0´

Now, we're talking. Looks like it could still be upgraded though...
''', '''
     /|
    |\|
    |||
    [|]
    |||
    [|]
    |||
    |||
 \_[[𐤓]]_/
    |\|
    |\|
    '0'

The final sword for the final level. How neat.
''', '''
     /|
    |^|
    |||
    |^|
    |||
    |^|
    |||
    |^|
.   |||   .
 \-([𐤎])-/
    |~|
    |~|
    'O'

The legendary sword, once lost, now found again.
'''],
  ['''
    /|      Λ
   //|     /ᚧ\\
  // |      |
 //  |      |
//   |      |
ᚧ    |      |
\\\   |      |
 \\\  |     /|\\
  \\\ |    //|\\\\
   \\\|    / Λ \\
    \|

The bow that began it all.
  ''', '''
    /|      Λ
   //|     /ᚶ\\
  // |      |
 //  |      |
//   |      |
ᚶ    |      |
\\\   |      |
 \\\  |     /|\\
  \\\ |    //|\\\\
   \\\|    / Λ \\
    \|

An upgraded bow. Nothing much seems to have changed.
  ''','''
    /|      Λ
   //|     /ᚸ\\
  // |      |
 //  |      |
//   |      |
ᚸ    |      |
\\\   |      |
 \\\  |     /|\\
  \\\ |    //|\\\\
   \\\|    / Λ \\
    \|

It is more powerful, yet the design remains the same...
  ''','''
    /|      Λ
   //|     /ᛞ\\
  // |      |
 //  |      |
//   |      |
ᛞ    |      |
\\\   |      |
 \\\  |     /|\\
  \\\ |    //|\\\\
   \\\|    / Λ \\
    \|

It seems the Nordic runes on the bow and arrow strengthen them.
  ''','''
    /|      Λ
   //|     /ᛃ\\
  // |      |
 //  |      |
//   |      |
ᛃ    |      |
\\\   |      |
 \\\  |     /|\\
  \\\ |    //|\\\\
   \\\|    / Λ \\
    \|

The final bow. Seems to shoot multiple arrows at once.
  '''],
   ['''
     Λ
    | |
    | |
    | |
    |-|
    |=|
    |Φ|
    |=|
    |-|
    | |
    | |
    | |
     V

The staff that set it all off.
''', '''
     Λ
   ~ O ~
    | |
    | |
    |-|
    |=|
    |Θ|
    |=|
    |-|
    | |
    | |
    | |
     V

A stronger staff, now with a ball of magic.
''', '''
     Λ
   ~*0*~
    |*|
    I I
    |-|
    I=I
    |Δ|
    I=I
    |-|
    I I
    | |
    I I
     V

Finally, a decent grip. Now it won't slip due to any monster blood on it.
''', '''
    *0*
*0* |*| *0*
|_|== ==|_|
    I I
    |-|
    I=I
    |Ψ|
    I=I
    |-|
    I I
    | |
    I I
     V

3 magic balls for triple the damage. The perfect weapon against the final level.
''', '''
        *0*
    *0* |*| *0*
 *0=|-|(`O´)|-|=0*
    *0* I I *0*
        *0*
      / I=I \\
      | |Ω| |
      \ I=I /
        |-|
        I I
        | |
        I I
         V

Overkill of the century. Comes with 2 additional handles.
''']] #flavour text and ascii art for weapons

current_arm = [0] #current best armor

arm_list = [["no class chosen", "no class chosen", "no class chosen", "no class chosen", "no class chosen"],
 ["Gambeson", "Linothorax", "Lorica Hamata", "Lamellar Armor", "Laminar Armor"],
  ["Dendra Panoply", "Chainmail Armor", "Brigandine", "Cuirass", "Hauberk"],
  ["Scale Armor", "Klivanion", "Almain Rivet", "White Armor", "Kasten-Brust Armor"]] #nested list of all armor in the game

flav_text_arm = [["no class chosen", "no class chosen", "no class chosen", "no class chosen", "no class chosen"], ['''
___       ___
|_ \-----/ _|
  |       |
  |       |
  |       |
  |_______|
''', '''
___       ___
|_ \-----/ _|
  |       |
  |       |
  |       |
  |_______|
''', '''
___       ___
|_ \-----/ _|
  |       |
  |       |
  |       |
  |_______|
''', '''
___       ___
|_ \-----/ _|
  |       |
  |       |
  |       |
  |_______|
''', '''
___       ___
|_ \-----/ _|
  |       |
  |       |
  |       |
  |_______|
'''], ['''
___       ___
|_ \-----/ _|
  |       |
  |       |
  |       |
  |_______|
''', '''
___       ___
|_ \-----/ _|
  |       |
  |       |
  |       |
  |_______|
''', '''
___       ___
|_ \-----/ _|
  |       |
  |       |
  |       |
  |_______|
''', '''
___       ___
|_ \-----/ _|
  |       |
  |       |
  |       |
  |_______|
''', '''
___       ___
|_ \-----/ _|
  |       |
  |       |
  |       |
  |_______|
'''], ['''
___       ___
|_ \-----/ _|
  |       |
  |       |
  |       |
  |_______|
''', '''
___       ___
|_ \-----/ _|
  |       |
  |       |
  |       |
  |_______|
''', '''
___       ___
|_ \-----/ _|
  |       |
  |       |
  |       |
  |_______|
''', '''
___       ___
|_ \-----/ _|
  |       |
  |       |
  |       |
  |_______|
''', '''
___       ___
|_ \-----/ _|
  |       |
  |       |
  |       |
  |_______|
''']] #flavour text and ascii art for armor

current_pets = [0, 0, 0, 0, 0, 0, 0] #current pets
pet_list = ["Blue Whale", "Guardian", "Lion",  "Skeleton", "Tarantula", "Tiger", "Black Cat"] #list of pets in game (able to get more than one of each)

location = [0] #current location
location_list = ["Private Island", "Spider's Den", "End Dimension", "Crimson Isle", "Final Jerry Arena"] #list of locations in game
#p_is == private island, s_den == spiders' den, end == end dimension, c_isle == crimson isle, fjb == final jerry arena

enemy_list = [[["Training Dummy"], #p_is enemy
 ["Jerry"]], #p_is boss
  [["Arachne's Keeper", "Spitter Spider", "Dasher Spider", "Voracious Spider", "Weaver Spider"], #s_den enemy
   ["Arachne"]], #s_den boss
    [["Watcher", "Zealot", "Obsidian Defender", "Endermite", "\"Special\" Zealot"], #end enemy
     ["The Superior Dragon"]], #end boss
      [["Bladesoul", "Barbarian Duke X", "The Mage Outlaw", "Ashfang", "The Magma Boss"], #c_isle enemy
       ["Kuudra"]], #c_isle boss
        ["Jerry"]] #fjb

enemy_stats = [[[[10, 0]], #p_is enemy
 [[20, 10]]], #p_is boss
  [[[300, 20], [145, 16], [140, 15], [145, 17], [150, 17]], #s_den enemy
   [[2000, 30]]], #s_den boss
    [[[950, 50], [200, 100], [1000, 20], [450, 20], [200, 62]], #end enemy
     [[1500, 50]]], #end boss
      [[[5000, 40], [7000, 40], [7000, 40], [5000, 50], [2000, 20]], #c_isle enemy
       [[10000, 60]]], #c_isle boss
        [[[20000, 150]]]] #final jerry

def op(): #shorthand for output.clear()
    output.clear()

def DMG(): #damage calculation
    x = ran.randint(0, 100)
    if x < stats_list[4]:
        return (5 + Base_DMG[0]) * (1 + (stats_list[2] / 100) ) * (1 + (stats_list[4] / 100) )
    else:
        return (5 + Base_DMG[0]) * (1 + (stats_list[2] / 100) )


def DMG_Red(): #damage reduction calculation
    return (stats_list[1]/(stats_list[1]+100))

def double(): #ferocity calculation
    x = ran.randint(0, 100)
    if x < stats_list[5]:
        return 2
    else:
        return 1

def SPD_Calc(): #speed calculation
    x = ran.randint(0, 100)
    if x < stats_list[6]:
        return True
    else:
        return False

def decide(): #decisions...
    while True:
        x = input("Confirm your choice (yes/no): ")
        if x == "yes":
            op()
            return True
        elif x == "no":
            op()
            return False
        else:
            print("Type yes or no only.")

def ability_select():
    op()
    while True:
        print(f"Current Mana: {currentMana[0]}")
        print(f"1: {ability_list[0]}\nMana Cost: {ability_cost[0]}\n")
        print(f"2: {ability_list[1]}\nMana Cost: {ability_cost[1]}\n")
        print(f"3: {ability_list[2]}\nMana Cost: {ability_cost[2]}\n")
        print(f"4: {ability_list[3]}\nMana Cost: {ability_cost[3]}\n")
        print(f"5: {ability_list[4]}\nMana Cost: {ability_cost[4]}\n")
        x = input("Select ability to use, empty to exit: ")
        if x in ["1","2","3","4","5",""]:
            if x == "1":
                if currentMana[0] >= ability_cost[0]:
                    currentMana[0] -= ability_cost[0]
                    print("You used Heal!")
                    stats_list[0] += round(Abt_Heal[0],1)
                    time.sleep(2)
                    return 0
                else:
                    print("You don't have enough mana to use this ability!")
                    time.sleep(2)
                    op()
            elif x == "2":
                if currentMana[0] >= ability_cost[1]:
                    currentMana[0] -= ability_cost[1]
                    print("You used Double Damage!")
                    Abt_Double[0] = 2
                    time.sleep(2)
                    return 0
                else:
                    print("You don't have enough mana to use this ability!")
                    time.sleep(2)
                    op()
            elif x == "3":
                if currentMana[0] >= ability_cost[2]:
                    currentMana[0] -= ability_cost[2]
                    print("You used Burn!")
                    Abt_Burn[0] = 5
                    time.sleep(2)
                    return 0
                else:
                    print("You don't have enough mana to use this ability!")
                    time.sleep(2)
                    op()
            elif x == "4":
                if currentMana[0] >= ability_cost[3]:
                    currentMana[0] -= ability_cost[3]
                    print("You used Dodge!")
                    time.sleep(2)
                    if ran.randint(0,10) < 7:
                        Abt_Dodge[0] = True
                    dodge_activated[0] = True
                    return 0
                else:
                    print("You don't have enough mana to use this ability!")
                    time.sleep(2)
                    op()
            elif x == "5":
                if currentMana[0] >= ability_cost[4]:
                    currentMana[0] -= ability_cost[4]
                    print("\"D4C!\" you cry, as you use all of you mana to open an interuniversal wormhole and pull out a weaker version of yourself to use as a meat shield.")
                    time.sleep(5)
                    abtMinionSummoned[0] = True
                    Abt_Minion[0] = (maxHP[0] * 0.2)
                    return 0
                else:
                    print("You don't have enough mana to use this ability!")
                    time.sleep(2)
                    op()
            elif x == "":
                op()
                return -1
        else:
            print("Enter 1, 2, 3, 4, 5 only or leave it empty to exit.")
            time.sleep(2)
            op()

def choose_class(): #choose your class
    while True:
        print("1: Berserker\n2: Archer\n3: Mage\n")
        class_choice = input("Choose your class: ")
        if class_choice == "1":
            print("The berserker has high melee damage and decent defense.")
            if decide():
                chosen_class[0] = 1
                return 1
                break
        elif class_choice == "2":
            print("The archer has decent ranged damage and decent defense.")
            if decide():
                chosen_class[0] = 2
                Base_DMG[0] = 5
                return 2
                break
        elif class_choice == "3":
            print("The mage has decent ability damage but horrendous defense")
            if decide():
                chosen_class[0] = 3
                Base_DMG[0] = 5
                stats_list[1] = 50
                return 3
                break
        else:
            print("Wrong selection")
            time.sleep(1)
            op()

def wpn_breakdown(): #weapon breakdown
    op()
    print(wpn_list[chosen_class[0]][current_wpn[0]])
    print(flav_text_wpn[chosen_class[0]][current_wpn[0]])
    x = input("Enter anything to exit.\n")

def arm_breakdown(): #armor breakdown
    op()
    print(arm_list[chosen_class[0]][current_arm[0]])
    print(flav_text_arm[chosen_class[0]][current_arm[0]])
    x = input("Enter anything to exit.\n")

def pets_breakdown(): #pets breakdown
    op()
    if len(current_pets) == 0:
        print("You don't have any pets!")
    else:
        print("You have: ")
        for pet in range(7):
            print(f"{current_pets[pet]} {pet_list[pet]}(s)")
    x = input("Enter anything to exit.\n")

def stats_screen(): #statistics screen
    while True:
        print(f"Your class is {classes[chosen_class[0]]}.\nHealth: {stats_list[0]}\nDefense: {stats_list[1]}\nStrength: {stats_list[2]}\nCritical Chance: {stats_list[3]}\nCritical Damage: {stats_list[4]}\nFerocity: {stats_list[5]}\nSpeed: {stats_list[6]}\n")
        print(f"Weapon: {wpn_list[chosen_class[0]][current_wpn[0]]}")
        print(f"Armor: {arm_list[chosen_class[0]][current_arm[0]]}")
        no_pets = 0
        for pet in range(7):
            no_pets += current_pets[pet]
        print(f"You have {no_pets} pet(s)!")
        print("\n1. Weapon breakdown\n2. Armor breakdown\n3. Pets breakdown\n4. Exit")
        scr_choice = input()
        time.sleep(1)
        if scr_choice == "1":
            wpn_breakdown()
            op()
        elif scr_choice == "2":
            arm_breakdown()
            op()
        elif scr_choice == "3":
            pets_breakdown()
            op()
        elif scr_choice == "4":
            op()
            break
        else:
            print("Invalid input. Enter only 1, 2, 3 or 4.")
            time.sleep(1)
            op()

def b_smith(): #blacksmith (upgrading armor and weapons)
    op()
    print('''
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢀⣀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣰⣿⣿⣷⡄⠀⠀⠀⠀⠀⠀⠀⢠⣄⣤⣦⣤⣀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢿⣿⣿⣿⡇⠀⠀⠀⠀⠀⠀⠀⠀⠈⠉⠛⠿⠟⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⣠⠀⠘⢿⣿⠟⠀⢠⡀⠀⠀⠀⠀⠀⠀⠀⣰⡗⠀⠀⠀⠀
⠀⠀⠀⠀⠀⢠⣾⠀⣿⠀⣷⣦⣤⣴⡇⢸⡇⠀⣷⠀⠀⠀⠀⣰⡟⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⣿⣿⠀⣿⣤⣈⣉⣉⣉⣠⣼⡇⠀⣿⡆⠀⠀⣰⡟⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⣿⣿⠀⣿⣿⣿⣿⣿⣿⣿⣿⡇⠀⣿⠇⠀⠀⠛⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠛⠛⠀⠛⠛⠛⠛⠛⠛⠛⠛⠃⠀⠛⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⣤⣤⣤⣤⣤⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣇⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠈⠻⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣷⣤⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠈⠙⠛⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⡿⠟⠋⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠿⠿⠿⣿⣿⣿⣿⣿⣿⣿⠿⠿⠿⠇⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣰⣿⣿⣿⣿⣿⣿⣿⣧⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⢀⣠⣾⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣦⡀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠘⠛⠛⠛⠛⠛⠛⠛⠛⠛⠛⠛⠛⠛⠛⠛⠛⠃⠀⠀
    ''')
    print("\nHey there! I'm the blacksmith.\nHere, let me upgrade that weapon and armor for you.")
    Base_DMG[0] += 10 * (location[0] + 1)
    stats_list[0] += 100 * (location[0] + 1)
    maxHP[0] += 100 * (location[0] + 1)
    stats_list[1] += 100 * (location[0] + 1)
    current_wpn[0] += 1
    current_arm[0] += 1
    time.sleep(1)
    print("There. Your items have been upgraded.")
    time.sleep(5)
    op()
    return 1

def pet_select():
    p1 = ran.randint(0,6)
    p2 = ran.randint(0,6)
    p3 = ran.randint(0,6)
    while True:
        if p1 == 0:
            print("1:")
            print("Blue Whale")
            print("It increases your Health!")
        elif p1 == 1:
            print("1:")
            print("Guardian")
            print("It increases your Defense!")
        elif p1 == 2:
            print("1:")
            print("Lion")
            print("It increases your Strength!")
        elif p1 == 3:
            print("1:")
            print("Skeleton")
            print("It increases your Critical Chance!")
        elif p1 == 4:
            print("1:")
            print("Tarantula")
            print("It increases your Critical Damage!")
        elif p1 == 5:
            print("1:")
            print("Tiger")
            print("It increases your Ferocity!")
        elif p1 == 6:
            print("1:")
            print("Black Cat")
            print("It increases your Speed!")
        print("")
        if p2 == 0:
            print("2:")
            print("Blue Whale")
            print("It increases your Health!")
        elif p2 == 1:
            print("2:")
            print("Guardian")
            print("It increases your Defense!")
        elif p2 == 2:
            print("2:")
            print("Lion")
            print("It increases your Strength!")
        elif p2 == 3:
            print("2:")
            print("Skeleton")
            print("It increases your Critical Chance!")
        elif p2 == 4:
            print("2:")
            print("Tarantula")
            print("It increases your Critical Damage!")
        elif p2 == 5:
            print("2:")
            print("Tiger")
            print("It increases your Ferocity!")
        elif p2 == 6:
            print("2:")
            print("Black Cat")
            print("It increases your Speed!")
        print("")
        if p3 == 0:
            print("3:")
            print("Blue Whale")
            print("It increases your Health!")
        elif p3 == 1:
            print("3:")
            print("Guardian")
            print("It increases your Defense!")
        elif p3 == 2:
            print("3:")
            print("Lion")
            print("It increases your Strength!")
        elif p3 == 3:
            print("3:")
            print("Skeleton")
            print("It increases your Critical Chance!")
        elif p3 == 4:
            print("3:")
            print("Tarantula")
            print("It increases your Critical Damage!")
        elif p3 == 5:
            print("3:")
            print("Tiger")
            print("It increases your Ferocity!")
        elif p3 == 6:
            print("3:")
            print("Black Cat")
            print("It increases your Speed!")
        print("")
        scr_choice = input("Enter your choice (1, 2 or 3):\n")
        if scr_choice == "1":
            if decide():
                print(f"You got a {pet_list[p1]}")
                current_pets[p1] += 1
                stats_list[p1] += 1
                if p1 == 0:
                    maxHP[0] += 1
                time.sleep(5)
                op()
                break
        elif scr_choice == "2":
            if decide():
                print(f"You got a {pet_list[p2]}")
                current_pets[p2] += 1
                stats_list[p2] += 1
                if p2 == 0:
                    maxHP[0] += 1
                time.sleep(5)
                break
        elif scr_choice == "3":
            if decide():
                print(f"You got a {pet_list[p3]}")
                current_pets[p3] += 1
                stats_list[p3] += 1
                if p3 == 0:
                    maxHP[0] += 1
                time.sleep(5)
                op()
                break
        else:
            print("Invalid input. Enter only 1, 2 or 3.")
            time.sleep(2)
            op()

def fight(enemy):
    e_HP = enemy_stats[location[0]][0][enemy][0]
    e_ATK = enemy_stats[location[0]][0][enemy][1]

    while True:
        print(f'''
You: {stats_list[0]} HP         {enemy_list[location[0]][0][enemy]}: {e_HP} HP
     {stats_list[2]} STR        {len(enemy_list[location[0]][0][enemy]) * " "}  {e_ATK} ATK
     {stats_list[3]} CC          {len(enemy_list[location[0]][0][enemy]) * " "}  25 CC
     {currentMana[0]} Mana\n
        ''')
        if abtMinionSummoned[0]:
            print(f'''

Minion: {Abt_Minion[0]}
            ''')
        time.sleep(2)

        print("\n1. Attack\n2. Use Ability")
        while True:
            choice = input()
            if choice == "1":
                damage = round(DMG() * double() * Abt_Double[0] ,1)
                break
            elif choice == "2":
                if ability_select() == 0:
                    damage = 0
                    break
                else:
                    print("\n1. Attack\n2. Use Ability")
            else:
                print("Enter only 1 or 2.")

        if ran.randint(0,100) < 25:
            e_damage = round(((e_ATK * (1 + (100 / 100) )) - (DMG_Red() * (e_ATK * (1 + (100 / 100) )))), 1)
        else:
            e_damage = round((e_ATK - (DMG_Red() * e_ATK)),1)

        if SPD_Calc():
            if damage > 0:
                print(f"You hit the {enemy_list[location[0]][0][enemy]} for {damage} damage!")
                e_HP -= damage
                time.sleep(2)

            if e_HP <= 0:
                print(f"You beat the {enemy_list[location[0]][0][enemy]}")
                time.sleep(2)
                op()
                pet_select()
                op()
                return True

            if abtMinionSummoned[0]:
                Abt_Minion[0] -= e_damage
                if dodge_activated[0] and not Abt_Dodge[0]:
                    print("You failed to dodge the attack. At least your minion took the hit for you.")
                    time.sleep(2)
                elif dodge_activated[0] and Abt_Dodge[0]:
                    print("You would have dodged the attack if it was coming for you. Unfortunately, your minion did not.")
                    time.sleep(3)
                    Abt_Dodge[0] = False
                print(f"Your minion was damaged for {e_damage} damage.")
                time.sleep(2)
            elif Abt_Dodge[0]:
                Abt_Dodge[0] = False
                print("You dodged the attack!")
                time.sleep(2)
            else:
                stats_list[0] -= e_damage
                if dodge_activated[0]:
                    print("You failed to dodge the attack.")
                    time.sleep(2)
                print(f"You were damaged for {e_damage} damage.")
                time.sleep(2)
            dodge_activated[0] = False

            if stats_list[0] <= 0:
                op()
                return False

            if Abt_Burn[0] > 0:
                print(f"The {enemy_list[location[0]][0][enemy]} was burned for {Abt_Burn[0]} damage!")
                e_HP -= Abt_Burn[0]
                Abt_Burn[0] -= 1
                time.sleep(2)

            if e_HP <= 0:
                print(f"You beat the {enemy_list[location[0]][0][enemy]}")
                time.sleep(2)
                op()
                pet_select()
                op()
                return True
        else:
            if abtMinionSummoned[0]:
                Abt_Minion[0] -= e_damage
                if dodge_activated[0]:
                    print("You were too slow to dodge the attack. At least your minion took the hit for you.")
                    time.sleep(2)
                    Abt_Dodge[0] = False
                print(f"Your minion was damaged for {e_damage} damage.")
                time.sleep(2)
            else:
                stats_list[0] -= e_damage
                if dodge_activated[0]:
                    print("You were too slow to dodge the attack.")
                    time.sleep(2)
                    Abt_Dodge[0] = False
                print(f"You were damaged for {e_damage} damage.")
                time.sleep(2)
            dodge_activated[0] = False

            if stats_list[0] <= 0:
                op()
                return False

            if damage > 0:
                print(f"You hit the {enemy_list[location[0]][0][enemy]} for {damage} damage!")
                e_HP -= damage
                time.sleep(2)

            if Abt_Burn[0] > 0:
                print(f"The {enemy_list[location[0]][0][enemy]} was burned for {Abt_Burn[0]} damage!")
                e_HP -= Abt_Burn[0]
                Abt_Burn[0] -= 1
                time.sleep(2)

            if e_HP <= 0:
                print(f"You beat the {enemy_list[location[0]][0][enemy]}")
                time.sleep(2)
                op()
                pet_select()
                op()
                return True

        if Abt_Minion[0] <= 0:
            abtMinionSummoned[0] = False

        currentMana[0] += manaRegen[0]
        if currentMana[0] > 50:
            currentMana[0] = 50

        op()

# Jerry
def jerry1(enemy):
    e_HP = enemy_stats[location[0]][1][enemy][0]
    e_ATK = enemy_stats[location[0]][1][enemy][1]

    print('''
  _______
 /       \\
|  O   O  |
|    |    |
|   ___   |
 \       /
 /_______\\
/         \\
|    |    |
|    |    |
|____|____|

    ''')
    print("How about you try against me?")
    time.sleep(10)
    op()
    while True:
        print(f'''
You: {stats_list[0]} HP         {enemy_list[location[0]][1][enemy]}: {e_HP} HP
     {stats_list[2]} STR        {len(enemy_list[location[0]][1][enemy]) * " "}  {e_ATK} ATK
     {stats_list[3]} CC          {len(enemy_list[location[0]][1][enemy]) * " "}  25 CC
     {currentMana[0]} Mana\n
        ''')

        if abtMinionSummoned[0]:
            print(f'''

Minion: {Abt_Minion[0]}
            ''')
        time.sleep(2)

        print("\n1. Attack\n2. Use Ability")
        while True:
            choice = input()
            if choice == "1":
                damage = round(DMG() * double() * Abt_Double[0],1)
                break
            elif choice == "2":
                if ability_select() == 0:
                    damage = 0
                    break
                else:
                    print("\n1. Attack\n2. Use Ability")
            else:
                print("Enter only 1 or 2.")

        if ran.randint(0,100) < 25:
            e_damage = round(((e_ATK * (1 + (100 / 100) )) - (DMG_Red() * (e_ATK * (1 + (100 / 100) )))), 1)
        else:
            e_damage = round((e_ATK - (DMG_Red() * e_ATK)),1)

        if SPD_Calc():
            if damage > 0:
                print(f"You hit {enemy_list[location[0]][1][enemy]} for {damage} damage!")
                e_HP -= damage
                time.sleep(2)

            if e_HP <= 0:
                print(f"You beat {enemy_list[location[0]][1][enemy]}")
                stats_list[0] = maxHP[0]
                time.sleep(2)
                print("You have been healed to full!")
                time.sleep(2)
                op()
                pet_select()
                op()
                return True

            if abtMinionSummoned[0]:
                Abt_Minion[0] -= e_damage
                if dodge_activated[0] and not Abt_Dodge[0]:
                    print("You failed to dodge the attack. At least your minion took the hit for you.")
                    time.sleep(2)
                elif dodge_activated[0] and Abt_Dodge[0]:
                    print("You would have dodged the attack if it was coming for you. Unfortunately, your minion did not.")
                    time.sleep(3)
                    Abt_Dodge[0] = False
                print(f"Your minion was damaged for {e_damage} damage.")
                time.sleep(2)
            elif Abt_Dodge[0]:
                Abt_Dodge[0] = False
                print("You dodged the attack!")
                time.sleep(2)
            else:
                stats_list[0] -= e_damage
                if dodge_activated[0]:
                    print("You failed to dodge the attack.")
                    time.sleep(2)
                print(f"You were damaged for {e_damage} damage.")
                time.sleep(2)
            dodge_activated[0] = False

            if stats_list[0] <= 0:
                op()
                return False

            if Abt_Burn[0] > 0:
                print(f"{enemy_list[location[0]][1][enemy]} was burned for {Abt_Burn[0]} damage!")
                e_HP -= Abt_Burn[0]
                Abt_Burn[0] -= 1
                time.sleep(2)

            if e_HP <= 0:
                print(f"You beat {enemy_list[location[0]][1][enemy]}")
                stats_list[0] = maxHP[0]
                time.sleep(2)
                print("You have been healed to full!")
                time.sleep(2)
                op()
                pet_select()
                op()
                return True
        else:
            if abtMinionSummoned[0]:
                Abt_Minion[0] -= e_damage
                if dodge_activated[0]:
                    print("You were too slow to dodge the attack. At least your minion took the hit for you.")
                    time.sleep(2)
                    Abt_Dodge[0] = False
                print(f"Your minion was damaged for {e_damage} damage.")
                time.sleep(2)
            else:
                stats_list[0] -= e_damage
                if dodge_activated[0]:
                    print("You were too slow to dodge the attack.")
                    time.sleep(2)
                    Abt_Dodge[0] = False
                print(f"You were damaged for {e_damage} damage.")
                time.sleep(2)
            dodge_activated[0] = False

            if stats_list[0] <= 0:
                op()
                return False

            if damage > 0:
                print(f"You hit {enemy_list[location[0]][1][enemy]} for {damage} damage!")
                e_HP -= damage
                time.sleep(2)

            if Abt_Burn[0] > 0:
                print(f"{enemy_list[location[0]][1][enemy]} was burned for {Abt_Burn[0]} damage!")
                e_HP -= Abt_Burn[0]
                Abt_Burn[0] -= 1
                time.sleep(2)

            if e_HP <= 0:
                print(f"You beat {enemy_list[location[0]][1][enemy]}")
                stats_list[0] = maxHP[0]
                time.sleep(2)
                print("You have been healed to full!")
                time.sleep(2)
                op()
                pet_select()
                op()
                return True

        if Abt_Minion[0] <= 0:
            abtMinionSummoned[0] = False

        currentMana[0] += manaRegen[0]
        if currentMana[0] > 50:
            currentMana[0] = 50

        op()

# FJB
def jerry2(enemy):
    e_HP = enemy_stats[location[0]][1][enemy][0]
    e_ATK = enemy_stats[location[0]][1][enemy][1]

    isStunned = False
    isShielded = False
    minion_HP = 2000
    print('''
  _______
 /       \\
|  O   O  |
|    |    |
|   ___   |
 \       /
 /_______\\
/         \\
|    |    |
|    |    |
|____|____|

    ''')
    print("Oh... You've beaten them all huh?")
    time.sleep(2)
    print("Here's one final challenge for you",end="")
    time.sleep(0.1)
    print(".",end="")
    time.sleep(0.1)
    print(".",end="")
    time.sleep(0.1)
    print(".")
    time.sleep(2)
    op()
    print('''
                                          _______
                                         /       \\
                                        |  O   O  |
                                        |    |    |
                                        |   ___   |
                                         \       /
                                       ＿ノヽ   ノ＼＿
                                    `/　`/ ⌒Ｙ⌒ Ｙ  ヽ
                                    ( 　(三ヽ人　 /　  |
                                    |　ﾉ⌒＼ ￣￣ヽ   ノ
                                    ヽ＿＿＿＞､＿_／
                                           ｜( 王 ﾉ〈
                                           /ﾐ`ー―彡\
                                          / ╰    ╯ \

    ''')
    print("                              領域展開 - Endless Abyss of Jerry")
    time.sleep(5)
    print("------------------------------------------------------------------------------------------------------")
    print("                        Start this battle with a DEF and SPD penalty")
    print("                          Jerry's attacks may stun you momentarily")
    print("                     Jerry's attacks will deal a Damage Over Time effect")
    print("                 Jerry may occasionally summon lightning bolts to hurl at you")
    print("              Jerry may occasionally summon inferior Jerries to act as a shield")
    print("    The damage you can deal to Jerry at any one time (excluding Ferocity) is capped at 2,000 DMG\n")
    stats_list[1] -= 100
    stats_list[6] -= 20
    time.sleep(20)
    op()
    while True:
        print(f'''
You: {stats_list[0]} HP         {enemy_list[location[0]][1][enemy]}: {e_HP} HP
     {stats_list[2]} STR        {len(enemy_list[location[0]][1][enemy]) * " "}  {e_ATK} ATK
     {stats_list[3]} CC          {len(enemy_list[location[0]][1][enemy]) * " "}  25 CC
     {currentMana[0]} Mana\n
        ''')

        if abtMinionSummoned[0]:
            print(f'''
Minion: {Abt_Minion[0]} HP
            ''', end="                        ")

        if isShielded:
            print(f'''
Inferior Jerry: {minion_HP} HP
            ''', end="")

        print("")
        time.sleep(2)

        if ran.randint(0,100) < 25:
            e_damage = round(((e_ATK * (1 + (100 / 100) )) - (DMG_Red() * (e_ATK * (1 + (100 / 100) )))), 1)
        else:
            e_damage = round((e_ATK - (DMG_Red() * e_ATK)),1)

        if isStunned:
            isStunned = False
            if abtMinionSummoned[0]:
                Abt_Minion[0] -= e_damage
                print(f"Your minion was damaged for {e_damage} damage.")
                time.sleep(2)
                print("Your minion is damaged by Jerry's Damage over Time effect!")
                time.sleep(2)
                Abt_Minion[0] -= 10

                if ran.randint(0,100) < 10:
                    print("Your minion got stunned!")
                    time.sleep(2)

                if ran.randint(0,100) < 25:
                    print("Your hairs stand on end as a lighting bolt sails towards your minion.")
                    time.sleep(2)
                    Abt_Minion[0] -= (1000 - (1000 * DMG_Red()))

            else:
                stats_list[0] -= e_damage
                print(f"You were damaged for {e_damage} damage.")
                time.sleep(2)
                print("You are damaged by Jerry's Damage over Time effect!")
                time.sleep(2)
                stats_list[0] -= 10

                if ran.randint(0,100) < 10:
                    print("You got stunned!")
                    time.sleep(2)
                    isStunned = True

                if ran.randint(0,100) < 25:
                    print("Your hairs stand on end as a lighting bolt sails towards you.")
                    time.sleep(2)
                    stats_list[0] -= (1000 - (1000 * DMG_Red()))

            if ran.randint(0,100) < 5:
                print("Jerry shields himself with an inferior Jerry.")
                time.sleep(2)
                isShielded = True

            if Abt_Burn[0] > 0:
                print(f"{enemy_list[location[0]][1][enemy]} was burned for {Abt_Burn[0]} damage!")
                e_HP -= Abt_Burn[0]
                Abt_Burn[0] -= 1
                time.sleep(2)

            if e_HP <= 0:
                stats_list[1] += 100
                stats_list[6] += 20
                print("You beat Jerry.")
                time.sleep(2)
                print("The game is now over.")
                time.sleep(2)
                print("I hope you had fun!")
                time.sleep(2)
                return True

        else:
            print("\n1. Attack\n2. Use Ability")
            while True:
                choice = input()
                if choice == "1":
                    damage = round(DMG() * Abt_Double[0],1)
                    break
                elif choice == "2":
                    if ability_select() == 0:
                        damage = 0
                        break
                    else:
                        print("\n1. Attack\n2. Use Ability")
                else:
                    print("Enter only 1 or 2.")

            if SPD_Calc():
                if damage > 0:
                    if isShielded:
                        print(f"You hit the inferior Jerry for {damage} damage!")
                        minion_HP -= damage * double()
                        if minion_HP <= 0:
                            isShielded = False
                            minion_HP = 2000
                    else:
                        print(f"You hit {enemy_list[location[0]][1][enemy]} for {damage} damage!")
                        if damage > 2000:
                            e_HP -= 2000 * double()
                        else:
                            e_HP -= damage * double()
                    time.sleep(2)

                if e_HP <= 0:
                    stats_list[1] += 100
                    stats_list[6] += 20
                    print("You beat Jerry.")
                    time.sleep(2)
                    print("The game is now over.")
                    time.sleep(2)
                    print("I hope you had fun!")
                    time.sleep(2)
                    return True

                if abtMinionSummoned[0]:
                    Abt_Minion[0] -= e_damage
                    if dodge_activated[0] and not Abt_Dodge[0]:
                        print("You failed to dodge the attack. At least your minion took the hit for you.")
                        time.sleep(2)
                    elif dodge_activated[0] and Abt_Dodge[0]:
                        print("You would have dodged the attack if it was coming for you. Unfortunately, your minion did not.")
                        time.sleep(3)
                        Abt_Dodge[0] = False
                    print(f"Your minion was damaged for {e_damage} damage.")
                    time.sleep(2)

                    print("Your minion is damaged by Jerry's Damage over Time effect!")
                    time.sleep(2)
                    Abt_Minion[0] -= 10

                    if ran.randint(0,100) < 10:
                        print("Your minion got stunned!")
                        time.sleep(2)

                    if ran.randint(0,100) < 25:
                        print("Your hairs stand on end as a lighting bolt sails towards your minion.")
                        time.sleep(2)
                        Abt_Minion[0] -= (1000 - (1000 * DMG_Red()))

                elif Abt_Dodge[0]:
                    Abt_Dodge[0] = False
                    print("You dodged the attack!")
                    time.sleep(2)

                    print("You are damaged by Jerry's Damage over Time effect!")
                    time.sleep(2)
                    stats_list[0] -= 9

                else:
                    stats_list[0] -= e_damage
                    if dodge_activated[0]:
                        print("You failed to dodge the attack.")
                        time.sleep(2)
                    print(f"You were damaged for {e_damage} damage.")
                    time.sleep(2)

                    print("You are damaged by Jerry's Damage over Time effect!")
                    time.sleep(2)
                    stats_list[0] -= 10

                    if ran.randint(0,100) < 10:
                        print("You got stunned!")
                        time.sleep(2)
                        isStunned = True

                    if ran.randint(0,100) < 25:
                        print("Your hairs stand on end as a lighting bolt sails towards you.")
                        time.sleep(2)
                        stats_list[0] -= (1000 - (1000 * DMG_Red()))

                if ran.randint(0,100) < 5:
                    print("Jerry shields himself with an inferior Jerry.")
                    time.sleep(2)
                    isShielded = True

                dodge_activated[0] = False


                if stats_list[0] <= 0:
                    op()
                    return False

                if Abt_Burn[0] > 0:
                    print(f"{enemy_list[location[0]][1][enemy]} was burned for {Abt_Burn[0]} damage!")
                    e_HP -= Abt_Burn[0]
                    Abt_Burn[0] -= 1
                    time.sleep(2)

                if e_HP <= 0:
                    stats_list[1] += 100
                    stats_list[6] += 20
                    print("You beat Jerry.")
                    time.sleep(2)
                    print("The game is now over.")
                    time.sleep(2)
                    print("I hope you had fun!")
                    time.sleep(2)
                    return True

            else:
                if abtMinionSummoned[0]:
                    Abt_Minion[0] -= e_damage
                    if dodge_activated[0] and not Abt_Dodge[0]:
                        print("You were too slow to dodge the attack. At least your minion took the hit for you.")
                        time.sleep(2)
                        Abt_Dodge[0] = False
                    print(f"Your minion was damaged for {e_damage} damage.")
                    time.sleep(2)

                    print("Your minion is damaged by Jerry's Damage over Time effect!")
                    time.sleep(2)
                    Abt_Minion[0] -= 10

                    if ran.randint(0,100) < 10:
                        print("Your minion got stunned!")
                        time.sleep(2)

                    if ran.randint(0,100) < 25:
                        print("Your hairs stand on end as a lighting bolt sails towards your minion.")
                        time.sleep(2)
                        Abt_Minion[0] -= (1000 - (1000 * DMG_Red()))

                else:
                    stats_list[0] -= e_damage
                    if dodge_activated[0]:
                        print("You were too slow to dodge the attack.")
                        time.sleep(2)
                        Abt_Dodge[0] = False
                    print(f"You were damaged for {e_damage} damage.")
                    time.sleep(2)

                    print("You are damaged by Jerry's Damage over Time effect!")
                    time.sleep(2)
                    stats_list[0] -= 10

                    if ran.randint(0,100) < 10:
                        print("You got stunned!")
                        time.sleep(2)
                        isStunned = True

                    if ran.randint(0,100) < 25:
                        print("Your hairs stand on end as a lighting bolt sails towards you.")
                        time.sleep(2)
                        stats_list[0] -= (1000 - (1000 * DMG_Red()))

                if ran.randint(0,100) < 5:
                    print("Jerry shields himself with an inferior Jerry.")
                    time.sleep(2)
                    isShielded = True

                dodge_activated[0] = False

                if stats_list[0] <= 0:
                    op()
                    return False

                if ran.randint(0,100) < 10:
                    print("You got stunned!")
                    time.sleep(2)
                    isStunned = True

                if isStunned:
                    if ran.randint(0,100) < 25:
                        print("Your hairs stand on end as a lighting bolt sails towards you.")
                        time.sleep(2)
                        stats_list[0] -= (1000 - (1000 * DMG_Red()))
                else:
                    if damage > 0:
                        if isShielded:
                            print(f"You hit the inferior Jerry for {damage} damage!")
                            minion_HP -= damage * double()
                            if minion_HP <= 0:
                                isShielded = False
                                minion_HP = 2000
                        else:
                            print(f"You hit {enemy_list[location[0]][1][enemy]} for {damage} damage!")
                            if damage > 2000:
                                e_HP -= 2000 * double()
                            else:
                                e_HP -= damage * double()
                        time.sleep(2)

                    if e_HP <= 0:
                        stats_list[1] += 100
                        stats_list[6] += 20
                        print("You beat Jerry.")
                        time.sleep(2)
                        print("The game is now over.")
                        time.sleep(2)
                        print("I hope you had fun!")
                        time.sleep(2)
                        return True

                    if ran.randint(0,100) < 25:
                        print("Your hairs stand on end as a lighting bolt sails towards you.")
                        time.sleep(2)
                        stats_list[0] -= (1000 - (1000 * DMG_Red()))

                if ran.randint(0,100) < 5:
                    print("Jerry shields himself with an inferior Jerry.")
                    time.sleep(2)
                    isShielded = True

                if Abt_Burn[0] > 0:
                    print(f"{enemy_list[location[0]][1][enemy]} was burned for {Abt_Burn[0]} damage!")
                    e_HP -= Abt_Burn[0]
                    Abt_Burn[0] -= 1
                    time.sleep(2)

                if e_HP <= 0:
                    stats_list[1] += 100
                    stats_list[6] += 20
                    print("You beat Jerry.")
                    time.sleep(2)
                    print("The game is now over.")
                    time.sleep(2)
                    print("I hope you had fun!")
                    time.sleep(2)
                    return True

        if Abt_Minion[0] <= 0:
            abtMinionSummoned[0] = False

        currentMana[0] += manaRegen[0]
        if currentMana[0] > 50:
            currentMana[0] = 50

            op()

# Arachne
def arachne(enemy):
    e_HP = enemy_stats[location[0]][1][enemy][0]
    e_ATK = enemy_stats[location[0]][1][enemy][1]

    print("As you enter Arachne's Den, you notice a slight squelching under your boots.")
    print("It seems some webbing is slowing you down.\n")
    print("Start this battle with a SPD penalty")
    stats_list[6] -= 10
    time.sleep(10)
    op()
    while True:
        print(f'''
You: {stats_list[0]} HP         {enemy_list[location[0]][1][enemy]}: {e_HP} HP
     {stats_list[2]} STR        {len(enemy_list[location[0]][1][enemy]) * " "}  {e_ATK} ATK
     {stats_list[3]} CC          {len(enemy_list[location[0]][1][enemy]) * " "}  25 CC
     {currentMana[0]} Mana\n
        ''')

        if abtMinionSummoned[0]:
            print(f'''

Minion: {Abt_Minion[0]} HP
            ''')
        time.sleep(2)

        print("\n1. Attack\n2. Use Ability")
        while True:
            choice = input()
            if choice == "1":
                damage = round(DMG() * double() * Abt_Double[0],1)
                break
            elif choice == "2":
                if ability_select() == 0:
                    damage = 0
                    break
                else:
                    print("\n1. Attack\n2. Use Ability")
            else:
                print("Enter only 1 or 2.")
        time.sleep(2)

        if ran.randint(0,100) < 25:
            e_damage = round(((e_ATK * (1 + (100 / 100) )) - (DMG_Red() * (e_ATK * (1 + (100 / 100) )))), 1)
        else:
            e_damage = round((e_ATK - (DMG_Red() * e_ATK)),1)

        if SPD_Calc():
            if damage > 0:
                print(f"You hit {enemy_list[location[0]][1][enemy]} for {damage} damage!")
                e_HP -= damage
                time.sleep(2)

            if e_HP <= 0:
                print(f"You beat {enemy_list[location[0]][1][enemy]}")
                stats_list[0] = maxHP[0]
                stats_list[6] += 10
                time.sleep(2)
                print("You have been healed to full!")
                time.sleep(2)
                op()
                pet_select()
                op()
                return True

            if abtMinionSummoned[0]:
                Abt_Minion[0] -= e_damage
                if dodge_activated[0] and not Abt_Dodge[0]:
                    print("You failed to dodge the attack. At least your minion took the hit for you.")
                    time.sleep(2)
                elif dodge_activated[0] and Abt_Dodge[0]:
                    print("You would have dodged the attack if it was coming for you. Unfortunately, your minion did not.")
                    time.sleep(3)
                    Abt_Dodge[0] = False
                print(f"Your minion was damaged for {e_damage} damage.")
                time.sleep(2)
            elif Abt_Dodge[0]:
                Abt_Dodge[0] = False
                print("You dodged the attack!")
                time.sleep(2)
            else:
                stats_list[0] -= e_damage
                if dodge_activated[0]:
                    print("You failed to dodge the attack.")
                    time.sleep(2)
                print(f"You were damaged for {e_damage} damage.")
                time.sleep(2)
            dodge_activated[0] = False

            if stats_list[0] <= 0:
                op()
                return False

            if Abt_Burn[0] > 0:
                print(f"{enemy_list[location[0]][1][enemy]} was burned for {Abt_Burn[0]} damage!")
                e_HP -= Abt_Burn[0]
                Abt_Burn[0] -= 1
                time.sleep(2)

            if e_HP <= 0:
                print(f"You beat {enemy_list[location[0]][1][enemy]}")
                stats_list[0] = maxHP[0]
                stats_list[6] += 10
                time.sleep(2)
                print("You have been healed to full!")
                time.sleep(2)
                op()
                pet_select()
                op()
                return True
        else:
            if abtMinionSummoned[0]:
                Abt_Minion[0] -= e_damage
                if dodge_activated[0]:
                    print("You were too slow to dodge the attack. At least your minion took the hit for you.")
                    time.sleep(2)
                    Abt_Dodge[0] = False
                print(f"Your minion was damaged for {e_damage} damage.")
                time.sleep(2)
            else:
                stats_list[0] -= e_damage
                if dodge_activated[0]:
                    print("You were too slow to dodge the attack.")
                    time.sleep(2)
                    Abt_Dodge[0] = False
                print(f"You were damaged for {e_damage} damage.")
                time.sleep(2)
            dodge_activated[0] = False

            if stats_list[0] <= 0:
                op()
                return False

            if damage > 0:
                print(f"You hit {enemy_list[location[0]][1][enemy]} for {damage} damage!")
                e_HP -= damage
                time.sleep(2)

            if Abt_Burn[0] > 0:
                print(f"{enemy_list[location[0]][1][enemy]} was burned for {Abt_Burn[0]} damage!")
                e_HP -= Abt_Burn[0]
                Abt_Burn[0] -= 1
                time.sleep(2)

            if e_HP <= 0:
                print(f"You beat {enemy_list[location[0]][1][enemy]}")
                stats_list[0] = maxHP[0]
                stats_list[6] += 10
                time.sleep(2)
                print("You have been healed to full!")
                time.sleep(2)
                op()
                pet_select()
                op()
                return True

        if Abt_Minion[0] <= 0:
            abtMinionSummoned[0] = False

        currentMana[0] += manaRegen[0]
        if currentMana[0] > 50:
            currentMana[0] = 50

        op()

# Superior Dragon
def drag(enemy):
    e_HP = enemy_stats[location[0]][1][enemy][0]
    e_ATK = enemy_stats[location[0]][1][enemy][1]

    print("Entering the Dragon's Lair, you are greeted by the smell of electricity all around.\n")
    print("The Superior Dragon will randomly send down bolts of lightning at you")
    time.sleep(10)
    op()
    while True:
        print(f'''
You: {stats_list[0]} HP         {enemy_list[location[0]][1][enemy]}: {e_HP} HP
     {stats_list[2]} STR        {len(enemy_list[location[0]][1][enemy]) * " "}  {e_ATK} ATK
     {stats_list[3]} CC          {len(enemy_list[location[0]][1][enemy]) * " "}  25 CC
     {currentMana[0]} Mana\n
        ''')

        if abtMinionSummoned[0]:
            print(f'''

Minion: {Abt_Minion[0]}
            ''')
        time.sleep(2)

        print("\n1. Attack\n2. Use Ability")
        while True:
            choice = input()
            if choice == "1":
                damage = round(DMG() * double() * Abt_Double[0],1)
                break
            elif choice == "2":
                if ability_select() == 0:
                    damage = 0
                    break
                else:
                    print("\n1. Attack\n2. Use Ability")
            else:
                print("Enter only 1 or 2.")

        if ran.randint(0,100) < 25:
            e_damage = round(((e_ATK * (1 + (100 / 100) )) - (DMG_Red() * (e_ATK * (1 + (100 / 100) )))), 1)
        else:
            e_damage = round((e_ATK - (DMG_Red() * e_ATK)),1)

        if SPD_Calc():
            if damage > 0:
                print(f"You hit {enemy_list[location[0]][1][enemy]} for {damage} damage!")
                e_HP -= damage
                time.sleep(2)

            if e_HP <= 0:
                print(f"You beat {enemy_list[location[0]][1][enemy]}")
                stats_list[0] = maxHP[0]
                time.sleep(2)
                print("You have been healed to full!")
                time.sleep(2)
                op()
                pet_select()
                op()
                return True

            if abtMinionSummoned[0]:
                Abt_Minion[0] -= e_damage

                if dodge_activated[0] and not Abt_Dodge[0]:
                    print("You failed to dodge the attack. At least your minion took the hit for you.")
                    time.sleep(2)

                elif dodge_activated[0] and Abt_Dodge[0]:
                    print("You would have dodged the attack if it was coming for you. Unfortunately, your minion did not.")
                    time.sleep(3)
                    Abt_Dodge[0] = False

                print(f"Your minion was damaged for {e_damage} damage.")
                time.sleep(2)

                if ran.randint(0,100) < 25:
                    print("Your hairs stand on end as a lighting bolt sails towards your minion.")
                    time.sleep(2)
                    Abt_Minion[0] -= (100 - (100 * DMG_Red()))

            elif Abt_Dodge[0]:
                Abt_Dodge[0] = False
                print("You dodged the attack!")
                time.sleep(2)

            else:
                stats_list[0] -= e_damage

                if dodge_activated[0]:
                    print("You failed to dodge the attack.")
                    time.sleep(2)

                print(f"You were damaged for {e_damage} damage.")
                time.sleep(2)

                if ran.randint(0,100) < 25:
                    print("Your hairs stand on end as a lighting bolt sails towards you.")
                    time.sleep(2)
                    stats_list[0] -= (100 - (100 * DMG_Red()))

            dodge_activated[0] = False

            if stats_list[0] <= 0:
                op()
                return False

            if Abt_Burn[0] > 0:
                print(f"{enemy_list[location[0]][1][enemy]} was burned for {Abt_Burn[0]} damage!")
                e_HP -= Abt_Burn[0]
                Abt_Burn[0] -= 1
                time.sleep(2)

            if e_HP <= 0:
                print(f"You beat {enemy_list[location[0]][1][enemy]}")
                stats_list[0] = maxHP[0]
                time.sleep(2)
                print("You have been healed to full!")
                time.sleep(2)
                op()
                pet_select()
                op()
                return True
        else:
            if abtMinionSummoned[0]:
                Abt_Minion[0] -= e_damage

                if dodge_activated[0]:
                    print("You were too slow to dodge the attack. At least your minion took the hit for you.")
                    time.sleep(2)
                    Abt_Dodge[0] = False

                print(f"Your minion was damaged for {e_damage} damage.")
                time.sleep(2)

                if ran.randint(0,100) < 25:
                    print("Your hairs stand on end as a lighting bolt sails towards your minion.")
                    time.sleep(2)
                    Abt_Minion[0] -= (100 - (100 * DMG_Red()))

            else:
                stats_list[0] -= e_damage

                if dodge_activated[0]:
                    print("You were too slow to dodge the attack.")
                    time.sleep(2)
                    Abt_Dodge[0] = False

                print(f"You were damaged for {e_damage} damage.")
                time.sleep(2)

                if ran.randint(0,100) < 25:
                    print("Your hairs stand on end as a lighting bolt sails towards you.")
                    time.sleep(2)
                    stats_list[0] -= (100 - (100 * DMG_Red()))

            dodge_activated[0] = False

            if stats_list[0] <= 0:
                op()
                return False

            if damage > 0:
                print(f"You hit {enemy_list[location[0]][1][enemy]} for {damage} damage!")
                e_HP -= damage
                time.sleep(2)

            if Abt_Burn[0] > 0:
                print(f"{enemy_list[location[0]][1][enemy]} was burned for {Abt_Burn[0]} damage!")
                e_HP -= Abt_Burn[0]
                Abt_Burn[0] -= 1
                time.sleep(2)

            if e_HP <= 0:
                print(f"You beat {enemy_list[location[0]][1][enemy]}")
                stats_list[0] = maxHP[0]
                time.sleep(2)
                print("You have been healed to full!")
                time.sleep(2)
                op()
                pet_select()
                op()
                return True

        if Abt_Minion[0] <= 0:
            abtMinionSummoned[0] = False

        currentMana[0] += manaRegen[0]
        if currentMana[0] > 50:
            currentMana[0] = 50

        op()

# Bladesoul
def bs(enemy):
    e_HP = enemy_stats[location[0]][1][enemy][0]
    e_ATK = enemy_stats[location[0]][1][enemy][1]

    minion_HP = 500
    isShielded = False
    print("Entering the Stronghold, you notice Bladesoul staring at you.")
    print("You start to get the funny feeling that there is more than one entity looking at you.\n")
    print("Bladesoul will occasionally summon a smaller Bladesoul as a meat shield.")
    time.sleep(10)
    op()
    while True:
        print(f'''
You: {stats_list[0]} HP         {enemy_list[location[0]][1][enemy]}: {e_HP} HP
     {stats_list[2]} STR        {len(enemy_list[location[0]][1][enemy]) * " "}  {e_ATK} ATK
     {stats_list[3]} CC          {len(enemy_list[location[0]][1][enemy]) * " "}  25 CC
     {currentMana[0]} Mana\n
        ''')

        if abtMinionSummoned[0]:
            print(f'''
Minion: {Abt_Minion[0]} HP
            ''', end="                        ")

        if isShielded:
            print(f'''
Lesser Bladesoul: {minion_HP} HP
            ''', end="")

        print("")
        time.sleep(2)

        if ran.randint(0,100) < 25:
            e_damage = round(((e_ATK * (1 + (100 / 100) )) - (DMG_Red() * (e_ATK * (1 + (100 / 100) )))), 1)
        else:
            e_damage = round((e_ATK - (DMG_Red() * e_ATK)),1)

        print("\n1. Attack\n2. Use Ability")
        while True:
            choice = input()
            if choice == "1":
                damage = round(DMG() * double() * Abt_Double[0],1)
                break
            elif choice == "2":
                if ability_select() == 0:
                    damage = 0
                    break
                else:
                    print("\n1. Attack\n2. Use Ability")
            else:
                print("Enter only 1 or 2.")

        if SPD_Calc():
            if damage > 0:
                if isShielded:
                    print(f"You hit the lesser Bladesoul for {damage} damage!")
                    minion_HP -= damage * double()
                    if minion_HP <= 0:
                        isShielded = False
                        minion_HP = 2000
                else:
                    print(f"You hit {enemy_list[location[0]][1][enemy]} for {damage} damage!")
                    e_HP -= damage
                    time.sleep(2)

            if e_HP <= 0:
                print(f"You beat {enemy_list[location[0]][1][enemy]}")
                stats_list[0] = maxHP[0]
                time.sleep(2)
                print("You have been healed to full!")
                time.sleep(2)
                op()
                pet_select()
                op()
                return True

            if abtMinionSummoned[0]:
                Abt_Minion[0] -= e_damage
                if dodge_activated[0] and not Abt_Dodge[0]:
                    print("You failed to dodge the attack. At least your minion took the hit for you.")
                    time.sleep(2)
                elif dodge_activated[0] and Abt_Dodge[0]:
                    print("You would have dodged the attack if it was coming for you. Unfortunately, your minion did not.")
                    time.sleep(3)
                    Abt_Dodge[0] = False
                print(f"Your minion was damaged for {e_damage} damage.")
                time.sleep(2)
            elif Abt_Dodge[0]:
                Abt_Dodge[0] = False
                print("You dodged the attack!")
                time.sleep(2)
            else:
                stats_list[0] -= e_damage
                if dodge_activated[0]:
                    print("You failed to dodge the attack.")
                    time.sleep(2)
                print(f"You were damaged for {e_damage} damage.")
                time.sleep(2)
            dodge_activated[0] = False

            if stats_list[0] <= 0:
                op()
                return False

            if Abt_Burn[0] > 0:
                print(f"{enemy_list[location[0]][1][enemy]} was burned for {Abt_Burn[0]} damage!")
                e_HP -= Abt_Burn[0]
                Abt_Burn[0] -= 1
                time.sleep(2)

            if e_HP <= 0:
                print(f"You beat {enemy_list[location[0]][1][enemy]}")
                stats_list[0] = maxHP[0]
                time.sleep(2)
                print("You have been healed to full!")
                time.sleep(2)
                op()
                pet_select()
                op()
                return True
        else:
            if abtMinionSummoned[0]:
                Abt_Minion[0] -= e_damage
                if dodge_activated[0]:
                    print("You were too slow to dodge the attack. At least your minion took the hit for you.")
                    time.sleep(2)
                    Abt_Dodge[0] = False
                print(f"Your minion was damaged for {e_damage} damage.")
                time.sleep(2)
            else:
                stats_list[0] -= e_damage
                if dodge_activated[0]:
                    print("You were too slow to dodge the attack.")
                    time.sleep(2)
                    Abt_Dodge[0] = False
                print(f"You were damaged for {e_damage} damage.")
                time.sleep(2)
            dodge_activated[0] = False

            if stats_list[0] <= 0:
                op()
                return False

            if damage > 0:
                if isShielded:
                    print(f"You hit the lesser Bladesoul for {damage} damage!")
                    minion_HP -= damage * double()
                    if minion_HP <= 0:
                        isShielded = False
                        minion_HP = 2000
                else:
                    print(f"You hit {enemy_list[location[0]][1][enemy]} for {damage} damage!")
                    e_HP -= damage
                    time.sleep(2)

            if Abt_Burn[0] > 0:
                print(f"{enemy_list[location[0]][1][enemy]} was burned for {Abt_Burn[0]} damage!")
                e_HP -= Abt_Burn[0]
                Abt_Burn[0] -= 1
                time.sleep(2)

            if e_HP <= 0:
                print(f"You beat {enemy_list[location[0]][1][enemy]}")
                stats_list[0] = maxHP[0]
                time.sleep(2)
                print("You have been healed to full!")
                time.sleep(2)
                op()
                pet_select()
                op()
                return True

        if Abt_Minion[0] <= 0:
            abtMinionSummoned[0] = False

        currentMana[0] += manaRegen[0]
        if currentMana[0] > 50:
            currentMana[0] = 50

        op()

# Barbarian Duke X
def bd(enemy):
    e_HP = enemy_stats[location[0]][1][enemy][0]
    e_ATK = enemy_stats[location[0]][1][enemy][1]

    isStunned = False
    print("Oh... you're approaching me?")
    print("Be warned, my club may stun you!\n")
    print("Barbarian Duke X's attacks have a chance of stunning you.")
    time.sleep(10)
    op()
    while True:
        print(f'''
You: {stats_list[0]} HP         {enemy_list[location[0]][1][enemy]}: {e_HP} HP
     {stats_list[2]} STR        {len(enemy_list[location[0]][1][enemy]) * " "}  {e_ATK} ATK
     {stats_list[3]} CC          {len(enemy_list[location[0]][1][enemy]) * " "}  25 CC
     {currentMana[0]} Mana\n
        ''')
        time.sleep(2)
        if abtMinionSummoned[0]:
            print(f'''

Minion: {Abt_Minion[0]}
            ''')
        time.sleep(2)

        if ran.randint(0,100) < 25:
            e_damage = round(((e_ATK * (1 + (100 / 100) )) - (DMG_Red() * (e_ATK * (1 + (100 / 100) )))), 1)
        else:
            e_damage = round((e_ATK - (DMG_Red() * e_ATK)),1)

        if isStunned:
            isStunned = False
            if abtMinionSummoned[0]:
                Abt_Minion[0] -= e_damage
                print(f"Your minion was damaged for {e_damage} damage.")
                time.sleep(2)

                if ran.randint(0,100) < 10:
                    print("Your minion got stunned!")
                    time.sleep(2)

            else:
                stats_list[0] -= e_damage
                print(f"You were damaged for {e_damage} damage.")
                time.sleep(2)

                if ran.randint(0,100) < 10:
                    print("You got stunned!")
                    time.sleep(2)
                    isStunned = True

            if Abt_Burn[0] > 0:
                print(f"{enemy_list[location[0]][1][enemy]} was burned for {Abt_Burn[0]} damage!")
                e_HP -= Abt_Burn[0]
                Abt_Burn[0] -= 1
                time.sleep(2)

            if e_HP <= 0:
                print(f"You beat {enemy_list[location[0]][1][enemy]}")
                stats_list[0] = maxHP[0]
                time.sleep(2)
                print("You have been healed to full!")
                time.sleep(2)
                op()
                pet_select()
                op()
                return True

        else:
            print("\n1. Attack\n2. Use Ability")
            while True:
                choice = input()
                if choice == "1":
                    damage = round(DMG() * double() * Abt_Double[0],1)
                    break
                elif choice == "2":
                    if ability_select() == 0:
                        damage = 0
                        break
                    else:
                        print("\n1. Attack\n2. Use Ability")
                else:
                    print("Enter only 1 or 2.")

            if SPD_Calc():
                if damage > 0:
                    print(f"You hit {enemy_list[location[0]][1][enemy]} for {damage} damage!")
                    e_HP -= damage
                    time.sleep(2)

                if e_HP <= 0:
                    print(f"You beat {enemy_list[location[0]][1][enemy]}")
                    stats_list[0] = maxHP[0]
                    time.sleep(2)
                    print("You have been healed to full!")
                    time.sleep(2)
                    op()
                    pet_select()
                    op()
                    return True

                if abtMinionSummoned[0]:
                    Abt_Minion[0] -= e_damage
                    if dodge_activated[0] and not Abt_Dodge[0]:
                        print("You failed to dodge the attack. At least your minion took the hit for you.")
                        time.sleep(2)
                    elif dodge_activated[0] and Abt_Dodge[0]:
                        print("You would have dodged the attack if it was coming for you. Unfortunately, your minion did not.")
                        time.sleep(3)
                        Abt_Dodge[0] = False
                    print(f"Your minion was damaged for {e_damage} damage.")
                    time.sleep(2)
                elif Abt_Dodge[0]:
                    Abt_Dodge[0] = False
                    print("You dodged the attack!")
                    time.sleep(2)
                else:
                    stats_list[0] -= e_damage
                    if dodge_activated[0]:
                        print("You failed to dodge the attack.")
                        time.sleep(2)
                    print(f"You were damaged for {e_damage} damage.")
                    time.sleep(2)
                dodge_activated[0] = False

                if stats_list[0] <= 0:
                    op()
                    return False

                if ran.randint(0,100) < 10:
                    print("You got stunned!")
                    time.sleep(2)
                    isStunned = True

                if Abt_Burn[0] > 0:
                    print(f"{enemy_list[location[0]][1][enemy]} was burned for {Abt_Burn[0]} damage!")
                    e_HP -= Abt_Burn[0]
                    Abt_Burn[0] -= 1
                    time.sleep(2)

                if e_HP <= 0:
                    print(f"You beat {enemy_list[location[0]][1][enemy]}")
                    stats_list[0] = maxHP[0]
                    time.sleep(2)
                    print("You have been healed to full!")
                    time.sleep(2)
                    op()
                    pet_select()
                    op()
                    return True
            else:
                if abtMinionSummoned[0]:
                    Abt_Minion[0] -= e_damage
                    if dodge_activated[0]:
                        print("You were too slow to dodge the attack. At least your minion took the hit for you.")
                        time.sleep(2)
                        Abt_Dodge[0] = False
                    print(f"Your minion was damaged for {e_damage} damage.")
                    time.sleep(2)
                else:
                    stats_list[0] -= e_damage
                    if dodge_activated[0]:
                        print("You were too slow to dodge the attack.")
                        time.sleep(2)
                        Abt_Dodge[0] = False
                    print(f"You were damaged for {e_damage} damage.")
                    time.sleep(2)
                dodge_activated[0] = False

                if stats_list[0] <= 0:
                    op()
                    return False

                if ran.randint(0,100) < 10:
                    print("You got stunned!")
                    time.sleep(2)
                    isStunned = True

                if not isStunned:
                    if damage > 0:
                        print(f"You hit {enemy_list[location[0]][1][enemy]} for {damage} damage!")
                        e_HP -= damage
                        time.sleep(2)

                if Abt_Burn[0] > 0:
                    print(f"{enemy_list[location[0]][1][enemy]} was burned for {Abt_Burn[0]} damage!")
                    e_HP -= Abt_Burn[0]
                    Abt_Burn[0] -= 1
                    time.sleep(2)

                if e_HP <= 0:
                    print(f"You beat {enemy_list[location[0]][1][enemy]}")
                    stats_list[0] = maxHP[0]
                    time.sleep(2)
                    print("You have been healed to full!")
                    time.sleep(2)
                    op()
                    pet_select()
                    op()
                    return True

        if Abt_Minion[0] <= 0:
            abtMinionSummoned[0] = False

        currentMana[0] += manaRegen[0]
        if currentMana[0] > 50:
            currentMana[0] = 50

        op()

# The Mage Outlaw
def mo(enemy):
    e_HP = enemy_stats[location[0]][1][enemy][0]
    e_ATK = enemy_stats[location[0]][1][enemy][1]

    print("The Mage Outlaw sees you approaching and hurriedly mutters a spell.")
    print("Before you know it, your armor seems lighter than before.\n")
    print("Start this battle with a DEF penalty.")
    stats_list[1] -= 50
    time.sleep(10)
    op()
    while True:
        print(f'''
You: {stats_list[0]} HP         {enemy_list[location[0]][1][enemy]}: {e_HP} HP
     {stats_list[2]} STR        {len(enemy_list[location[0]][1][enemy]) * " "}  {e_ATK} ATK
     {stats_list[3]} CC          {len(enemy_list[location[0]][1][enemy]) * " "}  25 CC
     {currentMana[0]} Mana\n
        ''')

        if abtMinionSummoned[0]:
            print(f'''

Minion: {Abt_Minion[0]} HP
            ''')
        time.sleep(2)

        print("\n1. Attack\n2. Use Ability")
        while True:
            choice = input()
            if choice == "1":
                damage = round(DMG() * double() * Abt_Double[0],1)
                break
            elif choice == "2":
                if ability_select() == 0:
                    damage = 0
                    break
                else:
                    print("\n1. Attack\n2. Use Ability")
            else:
                print("Enter only 1 or 2.")
        time.sleep(2)

        if ran.randint(0,100) < 25:
            e_damage = round(((e_ATK * (1 + (100 / 100) )) - (DMG_Red() * (e_ATK * (1 + (100 / 100) )))), 1)
        else:
            e_damage = round((e_ATK - (DMG_Red() * e_ATK)),1)

        if SPD_Calc():
            if damage > 0:
                print(f"You hit {enemy_list[location[0]][1][enemy]} for {damage} damage!")
                e_HP -= damage
                time.sleep(2)

            if e_HP <= 0:
                print(f"You beat {enemy_list[location[0]][1][enemy]}")
                stats_list[0] = maxHP[0]
                stats_list[1] += 50
                time.sleep(2)
                print("You have been healed to full!")
                time.sleep(2)
                op()
                pet_select()
                op()
                return True

            if abtMinionSummoned[0]:
                Abt_Minion[0] -= e_damage
                if dodge_activated[0] and not Abt_Dodge[0]:
                    print("You failed to dodge the attack. At least your minion took the hit for you.")
                    time.sleep(2)
                elif dodge_activated[0] and Abt_Dodge[0]:
                    print("You would have dodged the attack if it was coming for you. Unfortunately, your minion did not.")
                    time.sleep(3)
                    Abt_Dodge[0] = False
                print(f"Your minion was damaged for {e_damage} damage.")
                time.sleep(2)
            elif Abt_Dodge[0]:
                Abt_Dodge[0] = False
                print("You dodged the attack!")
                time.sleep(2)
            else:
                stats_list[0] -= e_damage
                if dodge_activated[0]:
                    print("You failed to dodge the attack.")
                    time.sleep(2)
                print(f"You were damaged for {e_damage} damage.")
                time.sleep(2)
            dodge_activated[0] = False

            if stats_list[0] <= 0:
                op()
                return False

            if Abt_Burn[0] > 0:
                print(f"{enemy_list[location[0]][1][enemy]} was burned for {Abt_Burn[0]} damage!")
                e_HP -= Abt_Burn[0]
                Abt_Burn[0] -= 1
                time.sleep(2)

            if e_HP <= 0:
                print(f"You beat {enemy_list[location[0]][1][enemy]}")
                stats_list[0] = maxHP[0]
                stats_list[1] += 50
                time.sleep(2)
                print("You have been healed to full!")
                time.sleep(2)
                op()
                pet_select()
                op()
                return True
        else:
            if abtMinionSummoned[0]:
                Abt_Minion[0] -= e_damage
                if dodge_activated[0]:
                    print("You were too slow to dodge the attack. At least your minion took the hit for you.")
                    time.sleep(2)
                    Abt_Dodge[0] = False
                print(f"Your minion was damaged for {e_damage} damage.")
                time.sleep(2)
            else:
                stats_list[0] -= e_damage
                if dodge_activated[0]:
                    print("You were too slow to dodge the attack.")
                    time.sleep(2)
                    Abt_Dodge[0] = False
                print(f"You were damaged for {e_damage} damage.")
                time.sleep(2)
            dodge_activated[0] = False

            if stats_list[0] <= 0:
                op()
                return False

            if damage > 0:
                print(f"You hit {enemy_list[location[0]][1][enemy]} for {damage} damage!")
                e_HP -= damage
                time.sleep(2)

            if Abt_Burn[0] > 0:
                print(f"{enemy_list[location[0]][1][enemy]} was burned for {Abt_Burn[0]} damage!")
                e_HP -= Abt_Burn[0]
                Abt_Burn[0] -= 1
                time.sleep(2)

            if e_HP <= 0:
                print(f"You beat {enemy_list[location[0]][1][enemy]}")
                stats_list[0] = maxHP[0]
                stats_list[1] += 50
                time.sleep(2)
                print("You have been healed to full!")
                time.sleep(2)
                op()
                pet_select()
                op()
                return True

        if Abt_Minion[0] <= 0:
            abtMinionSummoned[0] = False

        currentMana[0] += manaRegen[0]
        if currentMana[0] > 50:
            currentMana[0] = 50

        op()

# Ashfang
def af(enemy):
    e_HP = enemy_stats[location[0]][1][enemy][0]
    e_ATK = enemy_stats[location[0]][1][enemy][1]

    print("As you approach Ashfang, a barrier seems to emerge around it.\n")
    print("All damage (excluding Ferocity) to Ashfang is capped at 500")
    time.sleep(10)
    op()
    while True:
        print(f'''
You: {stats_list[0]} HP         {enemy_list[location[0]][1][enemy]}: {e_HP} HP
     {stats_list[2]} STR        {len(enemy_list[location[0]][1][enemy]) * " "}  {e_ATK} ATK
     {stats_list[3]} CC          {len(enemy_list[location[0]][1][enemy]) * " "}  25 CC
     {currentMana[0]} Mana\n
        ''')

        if abtMinionSummoned[0]:
            print(f'''

Minion: {Abt_Minion[0]}
            ''')
        time.sleep(2)

        print("\n1. Attack\n2. Use Ability")
        while True:
            choice = input()
            if choice == "1":
                damage = round(DMG() * Abt_Double[0],1)
                break
            elif choice == "2":
                if ability_select() == 0:
                    damage = 0
                    break
                else:
                    print("\n1. Attack\n2. Use Ability")
            else:
                print("Enter only 1 or 2.")

        if ran.randint(0,100) < 25:
            e_damage = round(((e_ATK * (1 + (100 / 100) )) - (DMG_Red() * (e_ATK * (1 + (100 / 100) )))), 1)
        else:
            e_damage = round((e_ATK - (DMG_Red() * e_ATK)),1)

        if SPD_Calc():
            if damage > 0:
                if damage > 500:
                    e_HP -= 500 * double()
                else:
                    e_HP -= damage * double()
                print(f"You hit {enemy_list[location[0]][1][enemy]} for {damage} damage!")
                time.sleep(2)

            if e_HP <= 0:
                print(f"You beat {enemy_list[location[0]][1][enemy]}")
                stats_list[0] = maxHP[0]
                time.sleep(2)
                print("You have been healed to full!")
                time.sleep(2)
                op()
                pet_select()
                op()
                return True

            if abtMinionSummoned[0]:
                Abt_Minion[0] -= e_damage
                if dodge_activated[0] and not Abt_Dodge[0]:
                    print("You failed to dodge the attack. At least your minion took the hit for you.")
                    time.sleep(2)
                elif dodge_activated[0] and Abt_Dodge[0]:
                    print("You would have dodged the attack if it was coming for you. Unfortunately, your minion did not.")
                    time.sleep(3)
                    Abt_Dodge[0] = False
                print(f"Your minion was damaged for {e_damage} damage.")
                time.sleep(2)
            elif Abt_Dodge[0]:
                Abt_Dodge[0] = False
                print("You dodged the attack!")
                time.sleep(2)
            else:
                stats_list[0] -= e_damage
                if dodge_activated[0]:
                    print("You failed to dodge the attack.")
                    time.sleep(2)
                print(f"You were damaged for {e_damage} damage.")
                time.sleep(2)
            dodge_activated[0] = False

            if stats_list[0] <= 0:
                op()
                return False

            if Abt_Burn[0] > 0:
                print(f"{enemy_list[location[0]][1][enemy]} was burned for {Abt_Burn[0]} damage!")
                e_HP -= Abt_Burn[0]
                Abt_Burn[0] -= 1
                time.sleep(2)

            if e_HP <= 0:
                print(f"You beat {enemy_list[location[0]][1][enemy]}")
                stats_list[0] = maxHP[0]
                time.sleep(2)
                print("You have been healed to full!")
                time.sleep(2)
                op()
                pet_select()
                op()
                return True
        else:
            if abtMinionSummoned[0]:
                Abt_Minion[0] -= e_damage
                if dodge_activated[0]:
                    print("You were too slow to dodge the attack. At least your minion took the hit for you.")
                    time.sleep(2)
                    Abt_Dodge[0] = False
                print(f"Your minion was damaged for {e_damage} damage.")
                time.sleep(2)
            else:
                stats_list[0] -= e_damage
                if dodge_activated[0]:
                    print("You were too slow to dodge the attack.")
                    time.sleep(2)
                    Abt_Dodge[0] = False
                print(f"You were damaged for {e_damage} damage.")
                time.sleep(2)
            dodge_activated[0] = False

            if stats_list[0] <= 0:
                op()
                return False

            if damage > 0:
                if damage > 500:
                    e_HP -= 500 * double()
                else:
                    e_HP -= damage * double()
                print(f"You hit {enemy_list[location[0]][1][enemy]} for {damage} damage!")
                time.sleep(2)

            if Abt_Burn[0] > 0:
                print(f"{enemy_list[location[0]][1][enemy]} was burned for {Abt_Burn[0]} damage!")
                e_HP -= Abt_Burn[0]
                Abt_Burn[0] -= 1
                time.sleep(2)

            if e_HP <= 0:
                print(f"You beat {enemy_list[location[0]][1][enemy]}")
                stats_list[0] = maxHP[0]
                time.sleep(2)
                print("You have been healed to full!")
                time.sleep(2)
                op()
                pet_select()
                op()
                return True

        if Abt_Minion[0] <= 0:
            abtMinionSummoned[0] = False

        currentMana[0] += manaRegen[0]
        if currentMana[0] > 50:
            currentMana[0] = 50

        op()

def mb(enemy):
    e_HP = enemy_stats[location[0]][1][enemy][0]
    e_ATK = enemy_stats[location[0]][1][enemy][1]

    print("In the distance, you notice the Magma Boss splashing in sonething orange.")
    print("As you get closer, you realise that it is lava.\n")
    print("The Magma Boss' attacks will have a Damage over Time effect that ignores armor.")
    time.sleep(10)
    op()
    while True:
        print(f'''
You: {stats_list[0]} HP         {enemy_list[location[0]][1][enemy]}: {e_HP} HP
     {stats_list[2]} STR        {len(enemy_list[location[0]][1][enemy]) * " "}  {e_ATK} ATK
     {stats_list[3]} CC          {len(enemy_list[location[0]][1][enemy]) * " "}  25 CC
     {currentMana[0]} Mana\n
        ''')

        if abtMinionSummoned[0]:
            print(f'''

Minion: {Abt_Minion[0]}
            ''')
        time.sleep(2)

        print("\n1. Attack\n2. Use Ability")
        while True:
            choice = input()
            if choice == "1":
                damage = round(DMG() * double() * Abt_Double[0],1)
                break
            elif choice == "2":
                if ability_select() == 0:
                    damage = 0
                    break
                else:
                    print("\n1. Attack\n2. Use Ability")
            else:
                print("Enter only 1 or 2.")

        if ran.randint(0,100) < 25:
            e_damage = round(((e_ATK * (1 + (100 / 100) )) - (DMG_Red() * (e_ATK * (1 + (100 / 100) )))), 1)
        else:
            e_damage = round((e_ATK - (DMG_Red() * e_ATK)),1)

        if SPD_Calc():
            if damage > 0:
                print(f"You hit {enemy_list[location[0]][1][enemy]} for {damage} damage!")
                e_HP -= damage
                time.sleep(2)

            if e_HP <= 0:
                print(f"You beat {enemy_list[location[0]][1][enemy]}")
                stats_list[0] = maxHP[0]
                time.sleep(2)
                print("You have been healed to full!")
                time.sleep(2)
                op()
                pet_select()
                op()
                return True

            if abtMinionSummoned[0]:
                Abt_Minion[0] -= e_damage
                if dodge_activated[0] and not Abt_Dodge[0]:
                    print("You failed to dodge the attack. At least your minion took the hit for you.")
                    time.sleep(2)
                elif dodge_activated[0] and Abt_Dodge[0]:
                    print("You would have dodged the attack if it was coming for you. Unfortunately, your minion did not.")
                    time.sleep(3)
                    Abt_Dodge[0] = False
                print(f"Your minion was damaged for {e_damage} damage.")
                time.sleep(2)
            elif Abt_Dodge[0]:
                Abt_Dodge[0] = False
                print("You dodged the attack!")
                time.sleep(2)
            else:
                stats_list[0] -= e_damage
                if dodge_activated[0]:
                    print("You failed to dodge the attack.")
                    time.sleep(2)
                print(f"You were damaged for {e_damage} damage.")
                time.sleep(2)
            dodge_activated[0] = False

            print("You are damaged by the Magma Boss' Damage over Time effect!")
            time.sleep(2)
            stats_list[0] -= 5

            if stats_list[0] <= 0:
                op()
                return False

            if Abt_Burn[0] > 0:
                print(f"{enemy_list[location[0]][1][enemy]} was burned for {Abt_Burn[0]} damage!")
                e_HP -= Abt_Burn[0]
                Abt_Burn[0] -= 1
                time.sleep(2)

            if e_HP <= 0:
                print(f"You beat {enemy_list[location[0]][1][enemy]}")
                stats_list[0] = maxHP[0]
                time.sleep(2)
                print("You have been healed to full!")
                time.sleep(2)
                op()
                pet_select()
                op()
                return True
        else:
            if abtMinionSummoned[0]:
                Abt_Minion[0] -= e_damage
                if dodge_activated[0]:
                    print("You were too slow to dodge the attack. At least your minion took the hit for you.")
                    time.sleep(2)
                    Abt_Dodge[0] = False
                print(f"Your minion was damaged for {e_damage} damage.")
                time.sleep(2)
            else:
                stats_list[0] -= e_damage
                if dodge_activated[0]:
                    print("You were too slow to dodge the attack.")
                    time.sleep(2)
                    Abt_Dodge[0] = False
                print(f"You were damaged for {e_damage} damage.")
                time.sleep(2)
            dodge_activated[0] = False


            print("You are damaged by the Magma Boss' Damage over Time effect!")
            time.sleep(2)
            stats_list[0] -= 5

            if stats_list[0] <= 0:
                op()
                return False

            if damage > 0:
                print(f"You hit {enemy_list[location[0]][1][enemy]} for {damage} damage!")
                e_HP -= damage
                time.sleep(2)

            if Abt_Burn[0] > 0:
                print(f"{enemy_list[location[0]][1][enemy]} was burned for {Abt_Burn[0]} damage!")
                e_HP -= Abt_Burn[0]
                Abt_Burn[0] -= 1
                time.sleep(2)

            if e_HP <= 0:
                print(f"You beat {enemy_list[location[0]][1][enemy]}")
                stats_list[0] = maxHP[0]
                time.sleep(2)
                print("You have been healed to full!")
                time.sleep(2)
                op()
                pet_select()
                op()
                return True

        if Abt_Minion[0] <= 0:
            abtMinionSummoned[0] = False

        currentMana[0] += manaRegen[0]
        if currentMana[0] > 50:
            currentMana[0] = 50

        op()

def kuudra(enemy):
    e_HP = enemy_stats[location[0]][1][enemy][0]
    e_ATK = enemy_stats[location[0]][1][enemy][1]

    print("Stepping into Kuudra's Hollow, you can't help but notice its sheer size.\n")
    print("Kuudra has an especially large amount of health.")
    time.sleep(10)
    op()
    while True:
        print(f'''
You: {stats_list[0]} HP         {enemy_list[location[0]][1][enemy]}: {e_HP} HP
     {stats_list[2]} STR        {len(enemy_list[location[0]][1][enemy]) * " "}  {e_ATK} ATK
     {stats_list[3]} CC          {len(enemy_list[location[0]][1][enemy]) * " "}  25 CC
     {currentMana[0]} Mana\n
        ''')

        if abtMinionSummoned[0]:
            print(f'''

Minion: {Abt_Minion[0]}
            ''')
        time.sleep(2)

        print("\n1. Attack\n2. Use Ability")
        while True:
            choice = input()
            if choice == "1":
                damage = round(DMG() * double() * Abt_Double[0],1)
                break
            elif choice == "2":
                if ability_select() == 0:
                    damage = 0
                    break
                else:
                    print("\n1. Attack\n2. Use Ability")
            else:
                print("Enter only 1 or 2.")

        if ran.randint(0,100) < 25:
            e_damage = round(((e_ATK * (1 + (100 / 100) )) - (DMG_Red() * (e_ATK * (1 + (100 / 100) )))), 1)
        else:
            e_damage = round((e_ATK - (DMG_Red() * e_ATK)),1)

        if SPD_Calc():
            if damage > 0:
                print(f"You hit {enemy_list[location[0]][1][enemy]} for {damage} damage!")
                e_HP -= damage
                time.sleep(2)

            if e_HP <= 0:
                print(f"You beat {enemy_list[location[0]][1][enemy]}")
                stats_list[0] = maxHP[0]
                time.sleep(2)
                print("You have been healed to full!")
                time.sleep(2)
                op()
                pet_select()
                op()
                return True

            if abtMinionSummoned[0]:
                Abt_Minion[0] -= e_damage
                if dodge_activated[0] and not Abt_Dodge[0]:
                    print("You failed to dodge the attack. At least your minion took the hit for you.")
                    time.sleep(2)
                elif dodge_activated[0] and Abt_Dodge[0]:
                    print("You would have dodged the attack if it was coming for you. Unfortunately, your minion did not.")
                    time.sleep(3)
                    Abt_Dodge[0] = False
                print(f"Your minion was damaged for {e_damage} damage.")
                time.sleep(2)
            elif Abt_Dodge[0]:
                Abt_Dodge[0] = False
                print("You dodged the attack!")
                time.sleep(2)
            else:
                stats_list[0] -= e_damage
                if dodge_activated[0]:
                    print("You failed to dodge the attack.")
                    time.sleep(2)
                print(f"You were damaged for {e_damage} damage.")
                time.sleep(2)
            dodge_activated[0] = False

            if stats_list[0] <= 0:
                op()
                return False

            if Abt_Burn[0] > 0:
                print(f"{enemy_list[location[0]][1][enemy]} was burned for {Abt_Burn[0]} damage!")
                e_HP -= Abt_Burn[0]
                Abt_Burn[0] -= 1
                time.sleep(2)

            if e_HP <= 0:
                print(f"You beat {enemy_list[location[0]][1][enemy]}")
                stats_list[0] = maxHP[0]
                time.sleep(2)
                print("You have been healed to full!")
                time.sleep(2)
                op()
                pet_select()
                op()
                return True
        else:
            if abtMinionSummoned[0]:
                Abt_Minion[0] -= e_damage
                if dodge_activated[0]:
                    print("You were too slow to dodge the attack. At least your minion took the hit for you.")
                    time.sleep(2)
                    Abt_Dodge[0] = False
                print(f"Your minion was damaged for {e_damage} damage.")
                time.sleep(2)
            else:
                stats_list[0] -= e_damage
                if dodge_activated[0]:
                    print("You were too slow to dodge the attack.")
                    time.sleep(2)
                    Abt_Dodge[0] = False
                print(f"You were damaged for {e_damage} damage.")
                time.sleep(2)
            dodge_activated[0] = False

            if stats_list[0] <= 0:
                op()
                return False

            if damage > 0:
                print(f"You hit {enemy_list[location[0]][1][enemy]} for {damage} damage!")
                e_HP -= damage
                time.sleep(2)

            if Abt_Burn[0] > 0:
                print(f"{enemy_list[location[0]][1][enemy]} was burned for {Abt_Burn[0]} damage!")
                e_HP -= Abt_Burn[0]
                Abt_Burn[0] -= 1
                time.sleep(2)

            if e_HP <= 0:
                print(f"You beat {enemy_list[location[0]][1][enemy]}")
                stats_list[0] = maxHP[0]
                time.sleep(2)
                print("You have been healed to full!")
                time.sleep(2)
                op()
                pet_select()
                op()
                return True

        if Abt_Minion[0] <= 0:
            abtMinionSummoned[0] = False

        currentMana[0] += manaRegen[0]
        if currentMana[0] > 50:
            currentMana[0] = 50

        op()

def p_is():
    location[0] = 0
    print(f"You are currently in your {location_list[location[0]]}\n")
    if notjerriedbefore[0]:
        print('''
  _______
 /       \\
|  O   O  |
|    |    |
|   ___   |
 \       /
 /_______\\
/         \\
|    |    |
|    |    |
|____|____|

Hi there! I'm Jerry, your tutorial for this game.
This game is very simple. You attack the opponent and hope that you don't die in the process. Have fun!
        ''')
        notjerriedbefore[0] = False

    time.sleep(10)
    op()
    if not fight(0):
        return False
    if not jerry1(0):
        return False
    if notbsmithedbefore[0]:
        b_smith()
        notbsmithedbefore[0] = False
        location_completed[0] = True
    return True

def s_den():
    location[0] = 1
    print(f"You are currently in the {location_list[location[0]]}.")
    x = ran.randint(15,30)
    while True:
        if bossCounter[1] != x:
            if not fight(ran.randint(0,4)):
                op()
                return False
            bossCounter[1] += 1
            op()
        else:
            if not arachne(0):
                op()
                return False
            op()
            if notbsmithedbefore[1]:
                b_smith()
                notbsmithedbefore[1] = False
                location_completed[1] = True
            return True

def end():
    location[0] = 2
    print(f"You are currently in the {location_list[location[0]]}.")
    x = ran.randint(15,30)
    while True:
        if bossCounter[2] != x:
            if not fight(ran.randint(0,4)):
                op()
                return False
            bossCounter[2] += 1
            op()
        else:
            if not drag(0):
                op()
                return False
            op()
            if notbsmithedbefore[2]:
                b_smith()
                notbsmithedbefore[2] = False
                location_completed[2] = True
            return True

def c_isle():
    location[0] = 3
    print(f"You are currently in the {location_list[location[0]]}.")
    print("This is a boss rush. Beat them, or die.")
    time.sleep(2)
    if not bs(0):
        return False
    if not bd(0):
        return False
    if not mo(0):
        return False
    if not af(0):
        return False
    if not mb(0):
        return False
    if not kuudra(0):
        return False
    if notbsmithedbefore[3]:
        b_smith()
        notbsmithedbefore[3] = False
        location_completed[3] = True
    return True

def fjb():
    location[0] = 4
    print(f"You are currently in the {location_list[location[0]]}.")
    time.sleep(2)
    if not jerry2(0):
        return False
    location_completed[4] = True
    return True

def fight_menu():
    while True:
        op()
        print("1. Private Island")
        if location_completed[0]:
            print("2. Spider's Den")
            if location_completed[1]:
                print("3. End Dimension")
                if location_completed[2]:
                    print("4. Crimson Isle")
                    if location_completed[3]:
                        print("5. Final Jerry Arena")
                        x = input()
                        if x in ["1", "2", "3", "4", "5"]:
                            print(f"To the {location_list[int(x) - 1]}!")
                            time.sleep(2)
                            op()
                            return (int(x) - 1)
                        else:
                            print("Enter 1, 2, 3, 4 or 5 only!")
                            time.sleep(2)
                            op()
                            continue
                    x = input()
                    if x in ["1", "2", "3", "4"]:
                        print(f"To the {location_list[int(x) - 1]}!")
                        time.sleep(2)
                        op()
                        return (int(x) - 1)
                    else:
                        print("Enter 1, 2, 3 or 4 only!")
                        time.sleep(2)
                        op()
                        continue
                x = input()
                if x in ["1", "2", "3"]:
                    print(f"To the {location_list[int(x) - 1]}!")
                    time.sleep(2)
                    op()
                    return (int(x) - 1)
                else:
                    print("Enter 1, 2 or 3 only!")
                    time.sleep(2)
                    op()
                    continue
            x = input()
            if x in ["1", "2"]:
                print(f"To the {location_list[int(x) - 1]}!")
                time.sleep(2)
                op()
                return (int(x) - 1)
            else:
                print("Enter 1 or 2 only!")
                time.sleep(2)
                op()
                continue
        x = input()
        if x in "1":
            print(f"To the {location_list[int(x) - 1]}!")
            time.sleep(2)
            op()
            return (int(x) - 1)
        else:
            print("Enter 1 only!")
            time.sleep(2)
            op()
            continue

def start():
    choose_class()
    while True:
        op()
        print("1. Stats Screen")
        print("2. Fight Menu")
        x = input()
        time.sleep(1)
        op()
        if x == "1":
            stats_screen()
        elif x == "2":
            y = fight_menu()
            if y == 0:
                if not p_is():
                    return False
            elif y == 1:
                if not s_den():
                    return False
            elif y == 2:
                if not end():
                    return False
            elif y == 3:
                if not c_isle():
                    return False
            elif y == 4:
                if not fjb():
                    return False
                else:
                    return True
        else:
            print("Enter 1 or 2 only!")

if not start():
    print("You died... Try again?")
else:
    print("You won!! Want to try again?")
